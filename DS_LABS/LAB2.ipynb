# %%
import pandas as pd
import numpy as np

#sample dataset
df=pd.DataFrame({ 'Age': [25,30,np.nan,40,35], 'Department': ['HR','Finance',np.nan,'IT','Software']})
#display original data set
print("Original dataset (With missing values):")
print(df)
#mean for numeric
df['Age']=df['Age'].fillna(df['Age'].mean())
#mode for categorical
df['Department']=df['Department'].fillna(df['Department'].mode()[0])
print(df)
# Out:
# Original dataset (With missing values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN        NaN
# 3  40.0         IT
# 4  35.0   Software
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0         IT
# 4  35.0   Software

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame({ 'Age': [25,30,np.nan,40,35], 'Department': ['HR','Finance',np.nan,'IT','Software']})
#Display original datasets
print("Original dataset (With missing values):")
print(df)
#forward fill(use previous values)
df_ffill=df.copy()
df_ffill.ffill(inplace=True)
print(df_ffill)
#backward fill (use next value)
df_bfill=df.copy()
df_bfill.bfill(inplace=True)
print(df_bfill)
# Out:
# Original dataset (With missing values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN        NaN
# 3  40.0         IT
# 4  35.0   Software
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0         IT
# 4  35.0   Software
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0         IT
# 3  40.0         IT
# 4  35.0   Software

# %%
#deletion(drop rows or columns)
import pandas as pd
import numpy as np

df=pd.DataFrame({ 'Age': [25,30,np.nan,40,35], 'Department': ['HR','Finance',np.nan,'IT','Software']})
#Display original datasets
print("Original dataset (With missing values):")
print(df)
#drop rows with missing values
df_drop_rows=df.dropna()
print("After dropping rows:\n",df_drop_rows)
#drop columns with missing values
df_drop_cols=df.dropna(axis=1)
print("After dropping columns:\n",df_drop_cols)
# Out:
# Original dataset (With missing values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN        NaN
# 3  40.0         IT
# 4  35.0   Software
# After dropping rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 3  40.0         IT
# 4  35.0   Software
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
import pandas as pd
#sample dataset with duplicates
df=pd.DataFrame({
    'ID':[1,2,2,3,4,4],
    'Name':['Alice','Bob','Bob','Charlie','David','David'],
    'Age':[25,30,30,35,40,40]
})

print("Original Data:\n",df)
#remove exact duplicates
df_exact=df.drop_duplicates()
print("\nAfter Exact match removal :\n",df_exact)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Exact match removal :
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
#removing dups (subset-based removal)
import pandas as pd
#sample dataset with duplicates
df=pd.DataFrame({
    'ID':[1,2,2,3,4,4],
    'Name':['Alice','Bob','Bob','Charlie','David','David'],
    'Age':[25,30,30,35,40,40]
})

print("Original Data:\n",df)
#remove dups based on id
df_subset_id=df.drop_duplicates(subset=['ID'])
print("\nAfter sub-set based removal (ID):\n",df_subset_id)
#remove dups based on name
df_subset_name=df.drop_duplicates(subset=['Name'])
print("\nAfter subset-based removal (name):\n",df_subset_name)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After sub-set based removal (ID):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
#
# After subset-based removal (name):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
#removing dups(correcting inconsistent formats)
import pandas as pd

df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5,2025', '2025.01.05']
})

print("Original data:\n", df)
#convert all datasets to standard ISO format (YYYY-MM-DD)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
# Original data:
#           Date
# 0  2025-01-05
# 1  05/01/2025
# 2  Jan 5,2025
# 3  2025.01.05
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
#Removing  Duplicates(Correcting Inconsistent Format)
#3.b.b Case Normalization
df=pd. DataFrame({
    'Name':['MOUNI','mouni','Mounitha','MoUnI']
})
print("Original Data:\n",df)

df['Name_lower']=df['Name'].str.lower()

df['Name_upper']=df['Name'].str.upper()

print("\n",df)
# Out:
# Original Data:
#         Name
# 0     MOUNI
# 1     mouni
# 2  Mounitha
# 3     MoUnI
#
#         Name Name_lower Name_upper
# 0     MOUNI      mouni      MOUNI
# 1     mouni      mouni      MOUNI
# 2  Mounitha   mounitha   MOUNITHA
# 3     MoUnI      mouni      MOUNI
